# %%
from random import random, randint

import numpy as np

NB_ANTS = 1000
GRID_MAX_SIZE = 100
NB_NODES = 20


tau = np.zeros((NB_NODES
                ,NB_NODES))
positions = np.array([[randint(0,GRID_MAX_SIZE),randint(0,GRID_MAX_SIZE)] for _ in range(NB_NODES) ])

# %%
from AntSystem import AntSystem

ant_system = AntSystem()

# %%
ant_system.simulate()
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]/Users/g0bel1n/PycharmProjects/ACO_Discovery/AntSystem.py:126: RuntimeWarning: invalid value encountered in true_divide
#   mat_probs = np.divide(m, m.sum(axis=1)[:, None])
# 100%|██████████| 200/200 [00:01<00:00, 142.81it/s]

# %%
ant_system.plot_graph()

# %%
ant_system.simulate()
