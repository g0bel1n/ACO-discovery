# %%
from AntSystem import AntSystem

ant_system = AntSystem(MAX_ITER=20, NB_NODES=20)

# %%
ant_system.simulate()
# Out:
# 100%|██████████| 20/20 [00:00<00:00, 144.09it/s]

# %%
ant_system.plot_graph()

# %%
ant_system.simulate()
